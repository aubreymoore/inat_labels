# %%
import pandas as pd
pd.options.display.max_rows = 100
import sqlite3 as db
import os
from pygbif import occurrences as occ
import datetime

# %%
INSECTS_OF_MICRONESIA_CSV = 'observations-201486.csv'
STUDENTS = 'albi345-2021.csv'

# %%
def get_inat_count(data):
    inat_count = 0
    for i, x in enumerate(data['results']):
        references = x.get('references', '')
        if 'inaturalist' in references:
            inat_count += 1
        #print(i+1, references)
    return inat_count

# %%
if os.path.exists('iom.db'):
    os.remove('iom.db')
conn = db.connect('iom.db')

df_iom = pd.read_csv(INSECTS_OF_MICRONESIA_CSV)
df_iom.to_sql('obs', conn)

df_students = pd.read_csv(STUDENTS)
df_students.to_sql('students', conn)

# %% [raw]
# sql = """
# select
#   "taxon_kingdom_name",
#   "taxon_phylum_name",
#   "taxon_subphylum_name",
#   "taxon_superclass_name",
#   "taxon_class_name",
#   "taxon_subclass_name",
#   "taxon_superorder_name",
#   "taxon_order_name",
#   "taxon_suborder_name",
#   "taxon_superfamily_name",
#   "taxon_family_name",
#   "taxon_subfamily_name",
#   "taxon_supertribe_name",
#   "taxon_tribe_name",
#   "taxon_subtribe_name",
#   "taxon_genus_name",
#   "taxon_genushybrid_name",
#   "taxon_species_name",
#   "taxon_hybrid_name",
#   "taxon_subspecies_name",
#   "taxon_variety_name",
#   "taxon_form_name"
# from obs;
# """

# %%
# %%time

mylist = []
for i, r in df_iom.iterrows():
    data = occ.search(limit=10000, country='GU', scientificName=r.scientific_name)
    total_count = data['count']
    if total_count > 0:
        inat_count = get_inat_count(data)
    else:
        inat_count = 0        
    if total_count == 0:
        mydict = {'user_login':r.user_login, 'id':r.id, 'total_count':0, 'inat_count':0, 'scientific_name':f"{r.scientific_name}", 
                  'GBIFchk':'WARNING: No previous GBIF records for this taxon on Guam'}
    else:
        if inat_count == total_count:
            mydict = {'user_login':r.user_login, 'id':r.id, 'total_count':total_count, 'inat_count':inat_count, 'scientific_name':f"{r.scientific_name}", 
                      'GBIFchk':f'WARNING: {total_count} previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
        else:
            mydict = {'user_login':r.user_login, 'id':r.id, 'total_count':total_count, 'inat_count':inat_count, 'scientific_name':f"{r.scientific_name}", 
                      'GBIFchk': f'OK: {total_count} previous GBIF records for this taxon on Guam'}
    print(mydict)
    mylist.append(mydict)
# Out:
# {'user_login': 'entomologist_of_mystery', 'id': 89457581, 'total_count': 5, 'inat_count': 1, 'scientific_name': 'Phaneroptera furcifera', 'GBIFchk': 'OK: 5 previous GBIF records for this taxon on Guam'}
# {'user_login': 'entomologist_of_mystery', 'id': 89458143, 'total_count': 61, 'inat_count': 32, 'scientific_name': 'Apis mellifera', 'GBIFchk': 'OK: 61 previous GBIF records for this taxon on Guam'}
# {'user_login': 'entomologist_of_mystery', 'id': 89459182, 'total_count': 11, 'inat_count': 1, 'scientific_name': 'Spoladea recurvalis', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'entomologist_of_mystery', 'id': 89459929, 'total_count': 33, 'inat_count': 3, 'scientific_name': 'Physomerus grossipes', 'GBIFchk': 'OK: 33 previous GBIF records for this taxon on Guam'}
# {'user_login': 'leeroysablan', 'id': 89582667, 'total_count': 184, 'inat_count': 181, 'scientific_name': 'Argiope appensa', 'GBIFchk': 'OK: 184 previous GBIF records for this taxon on Guam'}
# {'user_login': 'entomologist_of_mystery', 'id': 89716708, 'total_count': 16, 'inat_count': 0, 'scientific_name': 'Brontispa', 'GBIFchk': 'OK: 16 previous GBIF records for this taxon on Guam'}
# {'user_login': 'entomologist_of_mystery', 'id': 89717290, 'total_count': 16, 'inat_count': 0, 'scientific_name': 'Brontispa', 'GBIFchk': 'OK: 16 previous GBIF records for this taxon on Guam'}
# {'user_login': 'entomologist_of_mystery', 'id': 89745687, 'total_count': 46, 'inat_count': 8, 'scientific_name': 'Polistes stigma', 'GBIFchk': 'OK: 46 previous GBIF records for this taxon on Guam'}
# {'user_login': 'entomologist_of_mystery', 'id': 89748178, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'asanuma', 'id': 90009802, 'total_count': 0, 'inat_count': 0, 'scientific_name': 'Costelytra', 'GBIFchk': 'WARNING: No previous GBIF records for this taxon on Guam'}
# {'user_login': 'leeroysablan', 'id': 90618507, 'total_count': 0, 'inat_count': 0, 'scientific_name': 'Alucitidae', 'GBIFchk': 'WARNING: No previous GBIF records for this taxon on Guam'}
# {'user_login': 'aubreymoore', 'id': 91453154, 'total_count': 3, 'inat_count': 0, 'scientific_name': 'Scutigeromorpha', 'GBIFchk': 'OK: 3 previous GBIF records for this taxon on Guam'}
# {'user_login': 'leeroysablan', 'id': 92434944, 'total_count': 13, 'inat_count': 0, 'scientific_name': 'Chasmina tibialis', 'GBIFchk': 'OK: 13 previous GBIF records for this taxon on Guam'}
# {'user_login': 'leeroysablan', 'id': 92435754, 'total_count': 9, 'inat_count': 2, 'scientific_name': 'Spodoptera litura', 'GBIFchk': 'OK: 9 previous GBIF records for this taxon on Guam'}
# {'user_login': 'santosa11828', 'id': 92437483, 'total_count': 46, 'inat_count': 8, 'scientific_name': 'Polistes stigma', 'GBIFchk': 'OK: 46 previous GBIF records for this taxon on Guam'}
# {'user_login': 'jbirn', 'id': 92437541, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'jbirn', 'id': 92437655, 'total_count': 2, 'inat_count': 2, 'scientific_name': 'Curinus coeruleus', 'GBIFchk': 'WARNING: 2 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'santosa11828', 'id': 92437976, 'total_count': 46, 'inat_count': 8, 'scientific_name': 'Polistes stigma', 'GBIFchk': 'OK: 46 previous GBIF records for this taxon on Guam'}
# {'user_login': 'santosa11828', 'id': 92438057, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'chelstai', 'id': 92438174, 'total_count': 54, 'inat_count': 0, 'scientific_name': 'Stenocatantops', 'GBIFchk': 'OK: 54 previous GBIF records for this taxon on Guam'}
# {'user_login': 'aneladuenas', 'id': 92438243, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'uchan', 'id': 92438285, 'total_count': 40, 'inat_count': 0, 'scientific_name': 'Myllocerus', 'GBIFchk': 'OK: 40 previous GBIF records for this taxon on Guam'}
# {'user_login': 'berncie', 'id': 92438353, 'total_count': 46, 'inat_count': 8, 'scientific_name': 'Polistes stigma', 'GBIFchk': 'OK: 46 previous GBIF records for this taxon on Guam'}
# {'user_login': 'chelstai', 'id': 92438393, 'total_count': 61, 'inat_count': 32, 'scientific_name': 'Apis mellifera', 'GBIFchk': 'OK: 61 previous GBIF records for this taxon on Guam'}
# {'user_login': 'derpyinsight', 'id': 92438406, 'total_count': 61, 'inat_count': 32, 'scientific_name': 'Apis mellifera', 'GBIFchk': 'OK: 61 previous GBIF records for this taxon on Guam'}
# {'user_login': 'haanibettis', 'id': 92438523, 'total_count': 61, 'inat_count': 32, 'scientific_name': 'Apis mellifera', 'GBIFchk': 'OK: 61 previous GBIF records for this taxon on Guam'}
# {'user_login': 'aneladuenas', 'id': 92438534, 'total_count': 33, 'inat_count': 33, 'scientific_name': 'Oryctes rhinoceros', 'GBIFchk': 'WARNING: 33 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'uludongr', 'id': 92438539, 'total_count': 54, 'inat_count': 0, 'scientific_name': 'Stenocatantops', 'GBIFchk': 'OK: 54 previous GBIF records for this taxon on Guam'}
# {'user_login': 'berncie', 'id': 92438557, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'haanibettis', 'id': 92438561, 'total_count': 2, 'inat_count': 2, 'scientific_name': 'Curinus coeruleus', 'GBIFchk': 'WARNING: 2 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'eric1434', 'id': 92438583, 'total_count': 3996, 'inat_count': 100, 'scientific_name': 'Coleoptera', 'GBIFchk': 'OK: 3996 previous GBIF records for this taxon on Guam'}
# {'user_login': 'joanxfrndz', 'id': 92438591, 'total_count': 54, 'inat_count': 0, 'scientific_name': 'Stenocatantops', 'GBIFchk': 'OK: 54 previous GBIF records for this taxon on Guam'}
# {'user_login': 'joanxfrndz', 'id': 92438604, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'joanxfrndz', 'id': 92438624, 'total_count': 525, 'inat_count': 9, 'scientific_name': 'Coccinellidae', 'GBIFchk': 'OK: 525 previous GBIF records for this taxon on Guam'}
# {'user_login': 'derpyinsight', 'id': 92438762, 'total_count': 3996, 'inat_count': 100, 'scientific_name': 'Coleoptera', 'GBIFchk': 'OK: 3996 previous GBIF records for this taxon on Guam'}
# {'user_login': 'barcinasrita', 'id': 92438775, 'total_count': 2, 'inat_count': 2, 'scientific_name': 'Curinus coeruleus', 'GBIFchk': 'WARNING: 2 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'castrod', 'id': 92438857, 'total_count': 2, 'inat_count': 2, 'scientific_name': 'Curinus coeruleus', 'GBIFchk': 'WARNING: 2 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'castrod', 'id': 92438864, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'raympguinto', 'id': 92438874, 'total_count': 61, 'inat_count': 32, 'scientific_name': 'Apis mellifera', 'GBIFchk': 'OK: 61 previous GBIF records for this taxon on Guam'}
# {'user_login': 'uchan', 'id': 92438879, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'eric1434', 'id': 92438916, 'total_count': 992, 'inat_count': 7, 'scientific_name': 'Orthoptera', 'GBIFchk': 'OK: 992 previous GBIF records for this taxon on Guam'}
# {'user_login': 'santoss11532', 'id': 92438952, 'total_count': 61, 'inat_count': 32, 'scientific_name': 'Apis mellifera', 'GBIFchk': 'OK: 61 previous GBIF records for this taxon on Guam'}
# {'user_login': 'stewjohn', 'id': 92439044, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'santoss11532', 'id': 92439158, 'total_count': 11, 'inat_count': 0, 'scientific_name': 'Gonocephalum', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'uludongr', 'id': 92439211, 'total_count': 61, 'inat_count': 32, 'scientific_name': 'Apis mellifera', 'GBIFchk': 'OK: 61 previous GBIF records for this taxon on Guam'}
# {'user_login': 'stewjohn', 'id': 92439326, 'total_count': 61, 'inat_count': 32, 'scientific_name': 'Apis', 'GBIFchk': 'OK: 61 previous GBIF records for this taxon on Guam'}
# {'user_login': 'lauracaser', 'id': 92446483, 'total_count': 6, 'inat_count': 0, 'scientific_name': 'Eristalinus', 'GBIFchk': 'OK: 6 previous GBIF records for this taxon on Guam'}
# {'user_login': 'lauracaser', 'id':
previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'santosa11828', 'id': 101681357, 'total_count': 68, 'inat_count': 0, 'scientific_name': 'Gnathothlibus erotus', 'GBIFchk': 'OK: 68 previous GBIF records for this taxon on Guam'}
# {'user_login': 'todayis_renz', 'id': 101681478, 'total_count': 16, 'inat_count': 13, 'scientific_name': 'Melanitis leda', 'GBIFchk': 'OK: 16 previous GBIF records for this taxon on Guam'}
# {'user_login': 'todayis_renz', 'id': 101681903, 'total_count': 22, 'inat_count': 7, 'scientific_name': 'Polyrhachis dives', 'GBIFchk': 'OK: 22 previous GBIF records for this taxon on Guam'}
# {'user_login': 'todayis_renz', 'id': 101682496, 'total_count': 16, 'inat_count': 13, 'scientific_name': 'Melanitis leda', 'GBIFchk': 'OK: 16 previous GBIF records for this taxon on Guam'}
# {'user_login': 'todayis_renz', 'id': 101682607, 'total_count': 53, 'inat_count': 8, 'scientific_name': 'Erionota thrax', 'GBIFchk': 'OK: 53 previous GBIF records for this taxon on Guam'}
# {'user_login': 'santoss11532', 'id': 101683551, 'total_count': 45, 'inat_count': 45, 'scientific_name': 'Vespa tropica', 'GBIFchk': 'WARNING: 45 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'santosa11828', 'id': 101697678, 'total_count': 2, 'inat_count': 2, 'scientific_name': 'Rhynchium brunneum', 'GBIFchk': 'WARNING: 2 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'aubreymoore', 'id': 101728666, 'total_count': 2, 'inat_count': 0, 'scientific_name': 'Thyas regia', 'GBIFchk': 'OK: 2 previous GBIF records for this taxon on Guam'}
# {'user_login': 'aneladuenas', 'id': 101750692, 'total_count': 88, 'inat_count': 1, 'scientific_name': 'Anomala sulcatula', 'GBIFchk': 'OK: 88 previous GBIF records for this taxon on Guam'}
# {'user_login': 'aneladuenas', 'id': 101750790, 'total_count': 3, 'inat_count': 3, 'scientific_name': 'Delta pyriforme', 'GBIFchk': 'WARNING: 3 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'aneladuenas', 'id': 101785593, 'total_count': 0, 'inat_count': 0, 'scientific_name': 'Statilia pallida', 'GBIFchk': 'WARNING: No previous GBIF records for this taxon on Guam'}
# {'user_login': 'aneladuenas', 'id': 101798584, 'total_count': 389, 'inat_count': 6, 'scientific_name': 'Pantala flavescens', 'GBIFchk': 'OK: 389 previous GBIF records for this taxon on Guam'}
# {'user_login': 'todayis_renz', 'id': 101800928, 'total_count': 32, 'inat_count': 2, 'scientific_name': 'Cheilomenes sexmaculata', 'GBIFchk': 'OK: 32 previous GBIF records for this taxon on Guam'}
# {'user_login': 'uludongr', 'id': 101801204, 'total_count': 0, 'inat_count': 0, 'scientific_name': 'Cerambycinae', 'GBIFchk': 'WARNING: No previous GBIF records for this taxon on Guam'}
# {'user_login': 'derpyinsight', 'id': 101801214, 'total_count': 313, 'inat_count': 37, 'scientific_name': 'Protaetia', 'GBIFchk': 'OK: 313 previous GBIF records for this taxon on Guam'}
# {'user_login': 'todayis_renz', 'id': 101801313, 'total_count': 11, 'inat_count': 1, 'scientific_name': 'Spoladea recurvalis', 'GBIFchk': 'OK: 11 previous GBIF records for this taxon on Guam'}
# {'user_login': 'raympguinto', 'id': 101801392, 'total_count': 16, 'inat_count': 13, 'scientific_name': 'Melanitis leda', 'GBIFchk': 'OK: 16 previous GBIF records for this taxon on Guam'}
# {'user_login': 'todayis_renz', 'id': 101801509, 'total_count': 3274, 'inat_count': 295, 'scientific_name': 'Lepidoptera', 'GBIFchk': 'OK: 3274 previous GBIF records for this taxon on Guam'}
# {'user_login': 'joanxfrndz', 'id': 101801533, 'total_count': 2, 'inat_count': 0, 'scientific_name': 'Lucilia cuprina', 'GBIFchk': 'OK: 2 previous GBIF records for this taxon on Guam'}
# {'user_login': 'haanibettis', 'id': 101801726, 'total_count': 15, 'inat_count': 15, 'scientific_name': 'Periplaneta americana', 'GBIFchk': 'WARNING: 15 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'joanxfrndz', 'id': 101801732, 'total_count': 4, 'inat_count': 2, 'scientific_name': 'Aedes albopictus', 'GBIFchk': 'OK: 4 previous GBIF records for this taxon on Guam'}
# {'user_login': 'haanibettis', 'id': 101801861, 'total_count': 158, 'inat_count': 0, 'scientific_name': 'Elateridae', 'GBIFchk': 'OK: 158 previous GBIF records for this taxon on Guam'}
# {'user_login': 'haanibettis', 'id': 101801992, 'total_count': 0, 'inat_count': 0, 'scientific_name': 'Henosepilachna vigintisexpunctata', 'GBIFchk': 'WARNING: No previous GBIF records for this taxon on Guam'}
# {'user_login': 'haanibettis', 'id': 101802060, 'total_count': 54, 'inat_count': 0, 'scientific_name': 'Stenocatantops', 'GBIFchk': 'OK: 54 previous GBIF records for this taxon on Guam'}
# {'user_login': 'haanibettis', 'id': 101802122, 'total_count': 92, 'inat_count': 0, 'scientific_name': 'Aulacophora', 'GBIFchk': 'OK: 92 previous GBIF records for this taxon on Guam'}
# {'user_login': 'derpyinsight', 'id': 101802200, 'total_count': 15, 'inat_count': 15, 'scientific_name': 'Periplaneta americana', 'GBIFchk': 'WARNING: 15 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'haanibettis', 'id': 101802424, 'total_count': 0, 'inat_count': 0, 'scientific_name': 'Rutelinae', 'GBIFchk': 'WARNING: No previous GBIF records for this taxon on Guam'}
# {'user_login': 'haanibettis', 'id': 101802532, 'total_count': 313, 'inat_count': 37, 'scientific_name': 'Protaetia', 'GBIFchk': 'OK: 313 previous GBIF records for this taxon on Guam'}
# {'user_login': 'haanibettis', 'id': 
previous GBIF records for this taxon on Guam'}
# {'user_login': 'aneladuenas', 'id': 101809718, 'total_count': 36, 'inat_count': 3, 'scientific_name': 'Utetheisa pulchelloides', 'GBIFchk': 'OK: 36 previous GBIF records for this taxon on Guam'}
# {'user_login': 'bigalbalk', 'id': 101810481, 'total_count': 5, 'inat_count': 5, 'scientific_name': 'Evania appendigaster', 'GBIFchk': 'WARNING: 5 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'aneladuenas', 'id': 101811659, 'total_count': 0, 'inat_count': 0, 'scientific_name': 'Clogmia', 'GBIFchk': 'WARNING: No previous GBIF records for this taxon on Guam'}
# {'user_login': 'aneladuenas', 'id': 101811685, 'total_count': 2, 'inat_count': 0, 'scientific_name': 'Musca', 'GBIFchk': 'OK: 2 previous GBIF records for this taxon on Guam'}
# {'user_login': 'aneladuenas', 'id': 101811753, 'total_count': 0, 'inat_count': 0, 'scientific_name': 'Myrmicinae', 'GBIFchk': 'WARNING: No previous GBIF records for this taxon on Guam'}
# {'user_login': 'aneladuenas', 'id': 101811773, 'total_count': 3, 'inat_count': 3, 'scientific_name': 'Odontomachus simillimus', 'GBIFchk': 'WARNING: 3 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'uchan', 'id': 101852906, 'total_count': 86, 'inat_count': 10, 'scientific_name': 'Agrius convolvuli', 'GBIFchk': 'OK: 86 previous GBIF records for this taxon on Guam'}
# {'user_login': 'uchan', 'id': 101853425, 'total_count': 1, 'inat_count': 1, 'scientific_name': 'Wasmannia auropunctata', 'GBIFchk': 'WARNING: 1 previous GBIF records for this taxon on Guam; but they are all from iNaturalist'}
# {'user_login': 'uchan', 'id': 101862681, 'total_count': 0, 'inat_count': 0, 'scientific_name': 'Coccoidea', 'GBIFchk': 'WARNING: No previous GBIF records for this taxon on Guam'}
# {'user_login': 'keandra24', 'id': 101867880, 'total_count': 131, 'inat_count': 59, 'scientific_name': 'Papilio polytes', 'GBIFchk': 'OK: 131 previous GBIF records for this taxon on Guam'}
# {'user_login': 'santoss11532', 'id': 101903463, 'total_count': 42, 'inat_count': 10, 'scientific_name': 'Protaetia pryeri', 'GBIFchk': 'OK: 42 previous GBIF records for this taxon on Guam'}
# CPU times: user 18.1 s, sys: 2.05 s, total: 20.2 s
# Wall time: 21min 32s

# %%
df_GBIFcheck = pd.DataFrame.from_dict(mylist)

# %%
df_GBIFcheck.to_sql('GBIFcheck', conn)

# %%
print('FINISHED')
# Out:
# FINISHED

# %%
len(df_iom.columns)
# Out:
# 66

# %%
df_iom1 = df_iom.dropna(how='all', axis=1)
len(df_iom1.columns)
# Out:
# 50

# %%
df_iom1.columns
# Out:
# Index(['id', 'observed_on_string', 'observed_on', 'time_observed_at',
#        'time_zone', 'user_id', 'user_login', 'created_at', 'updated_at',
#        'quality_grade', 'license', 'url', 'image_url', 'description',
#        'num_identification_agreements', 'num_identification_disagreements',
#        'captive_cultivated', 'oauth_application_id', 'place_guess', 'latitude',
#        'longitude', 'positional_accuracy', 'public_positional_accuracy',
#        'taxon_geoprivacy', 'coordinates_obscured', 'positioning_method',
#        'positioning_device', 'place_state_name', 'place_admin1_name',
#        'species_guess', 'scientific_name', 'common_name', 'iconic_taxon_name',
#        'taxon_id', 'taxon_kingdom_name', 'taxon_phylum_name',
#        'taxon_subphylum_name', 'taxon_class_name', 'taxon_subclass_name',
#        'taxon_superorder_name', 'taxon_order_name', 'taxon_suborder_name',
#        'taxon_superfamily_name', 'taxon_family_name', 'taxon_subfamily_name',
#        'taxon_tribe_name', 'taxon_subtribe_name', 'taxon_genus_name',
#        'taxon_species_name', 'taxon_subspecies_name'],
#       dtype='object')

# %%
df_merged = df_iom1.merge(df_GBIFcheck, on='id')

# %%
df_merged.columns
# Out:
# Index(['id', 'observed_on_string', 'observed_on', 'time_observed_at',
#        'time_zone', 'user_id', 'user_login_x', 'created_at', 'updated_at',
#        'quality_grade', 'license', 'url', 'image_url', 'description',
#        'num_identification_agreements', 'num_identification_disagreements',
#        'captive_cultivated', 'oauth_application_id', 'place_guess', 'latitude',
#        'longitude', 'positional_accuracy', 'public_positional_accuracy',
#        'taxon_geoprivacy', 'coordinates_obscured', 'positioning_method',
#        'positioning_device', 'place_state_name', 'place_admin1_name',
#        'species_guess', 'scientific_name_x', 'common_name',
#        'iconic_taxon_name', 'taxon_id', 'taxon_kingdom_name',
#        'taxon_phylum_name', 'taxon_subphylum_name', 'taxon_class_name',
#        'taxon_subclass_name', 'taxon_superorder_name', 'taxon_order_name',
#        'taxon_suborder_name', 'taxon_superfamily_name', 'taxon_family_name',
#        'taxon_subfamily_name', 'taxon_tribe_name', 'taxon_subtribe_name',
#        'taxon_genus_name', 'taxon_species_name', 'taxon_subspecies_name',
#        'user_login_y', 'total_count', 'inat_count', 'scientific_name_y',
#        'GBIFchk'],
#       dtype='object')

# %%
def generate_html_report(mytable_html, student_name):
    #timestamp = datetime.utcnow()
    html = f'''
        <html>
            <header>
                <meta charset="utf-8">
                <meta name="viewport" content="width=device-width, initial-scale=1">
                <title>mat_cit_chk</title>
                <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bulma@0.9.3/css/bulma.min.css">
            </header>
            <body>
                <section class="section">
                    <div class="container">
                        {mytable_html}
                    </div>
                </section>
            </body>
        </html>        
        '''
    with open(f'{student_name}.html', 'w') as f:
        f.write(html)

# %%
def create_html_table(user_login):

    df_temp = df_merged[[
        'user_login_x',
        'url',
        'taxon_order_name',
        'taxon_suborder_name', 
#         'taxon_superfamily_name', 
        'taxon_family_name',
#         'taxon_subfamily_name', 
#         'taxon_tribe_name', 
#         'taxon_subtribe_name',
        'taxon_genus_name', 
        'taxon_species_name', 
#         'taxon_subspecies_name',        
        'scientific_name_x',
        'GBIFchk']][df_merged.user_login_x==user_login]

    df_temp.sort_values([
        'taxon_order_name',
        'taxon_suborder_name', 
#         'taxon_superfamily_name', 
        'taxon_family_name',
#         'taxon_subfamily_name', 
#         'taxon_tribe_name', 
#         'taxon_subtribe_name',
        'taxon_genus_name', 
        'taxon_species_name'], inplace=True)
    
    df_temp.columns = ['user', 'url', 'order', 'suborder', 'family', 'genus', 'species','scientific_name','GBIFchk']

    return df_temp.to_html(index=False)
    
# create_html_table('entomologist_of_mystery')

# %%
for i,r in df_students.iterrows():
    print(r['name'])
    mytable_html = create_html_table(r['inat_user_login'])
    generate_html_report(mytable_html, r['name'])
# Out:
# Chelsea Taitano
# Risel Uludong
# Touraine E. Williams
# Anela Duenas
# Audrey Marie Santos
# Julia Birn
# Ray Mark Guinto
# Stephenie Andriana Santos
# Rachel Mungon
# Samantha Gilinug
# Haani Bettis
# Rita Barcinas
# Stewart Johnny
# Tarsis Maddison
# Eric Delfin
# Daniel Castro
# Lawrenz Gaerlon
# Kenneth Bigalbal
# Joan Fernandez
# Kyle Quiambao
# Laura Caser
# Berncie Lizama
